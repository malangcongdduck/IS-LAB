# %% [markdown]
# # 결과 모음

# %% [markdown]
# # <Y=HDL>
# ## 1. 임의+선별
# ### <오차범위 3>
# - train set prediction accuracy(+-3): 29.89 % <br>
# - test set prediction accuracy(+-3): 16.90 % <br>
# <br>
#
# ### <오차범위 5>
# - train set prediction accuracy(+-5): 44.84 % <br>
# - test set prediction accuracy(+-5): 32.39 % <br>
# <br>
#
# ### <오차범위 10>
# - train set prediction accuracy(+-10): 74.38 % <br>
# - test set prediction accuracy(+-10): 61.97 % <br>
# <br>
#
# ### <오차범위 20>
# - train set prediction accuracy(+-20): 95.02 % <br>
# - test set prediction accuracy(+-20): 92.96 % <br>
#
# ## 2. 임의+선별+PSQI
# ### <오차범위 3>
# - train set prediction accuracy(+-3): 65.48 % <br>
# - test set prediction accuracy(+-3): 22.54 % <br>
# <br>
#
# ### <오차범위 5>
# - train set prediction accuracy(+-5): 82.92 % <br>
# - test set prediction accuracy(+-5): 38.03 % <br>
# <br>
#
# ### <오차범위 10>
# - train set prediction accuracy(+-10): 96.09 % <br>
# - test set prediction accuracy(+-10): 57.75 % <br>
# <br>
#
# ### <오차범위 20>
# - train set prediction accuracy(+-20): 100.00 % <br>
# - test set prediction accuracy(+-20): 87.32 % <br>
#
#
# ## 3. PSQI+AGE+SEX+BMI+Fat+Fat_percentage+Waist
# ### <오차범위 3>
# - train set prediction accuracy(+-3): 59.79 % <br>
# - test set prediction accuracy(+-3): 25.35 % <br>
# <br>
#
# ### <오차범위 5>
# - train set prediction accuracy(+-5): 78.65 % <br>
# - test set prediction accuracy(+-5): 47.89 % <br>
# <br>
#
# ### <오차범위 10>
# - train set prediction accuracy(+-10): 96.09 % <br>
# - test set prediction accuracy(+-10): 77.46 % <br>
# <br>
#
# ### <오차범위 20>
# - train set prediction accuracy(+-20): 99.64 % <br>
# - test set prediction accuracy(+-20): 98.59 % <br>
#
# ## 4. PSQI+AGE+SEX+BMI
# ### <오차범위 3>
# - train set prediction accuracy(+-3): 58.72 % <br>
# - test set prediction accuracy(+-3): 28.17 % <br>
# <br>
#
# ### <오차범위 5>
# - train set prediction accuracy(+-5): 77.94 % <br>
# - test set prediction accuracy(+-5): 49.30 % <br>
# <br>
#
# ### <오차범위 10>
# - train set prediction accuracy(+-10): 94.66 % <br>
# - test set prediction accuracy(+-10): 81.69 % <br>
# <br>
#
# ### <오차범위 20>
# - train set prediction accuracy(+-20): 99.64 % <br>
# - test set prediction accuracy(+-20): 98.59 % <br>

# %% [markdown]
# # <Y=LDL>
# ## 1. 임의+선별
# ### <오차범위 3>
# - train set prediction accuracy(+-3): 11.03 % <br>
# - test set prediction accuracy(+-3): 7.04 % <br>
# <br>
#
# ### <오차범위 5>
# - train set prediction accuracy(+-5): 21.35 % <br>
# - test set prediction accuracy(+-5): 12.68 % <br>
# <br>
#
# ### <오차범위 10>
# - train set prediction accuracy(+-10): 39.86 % <br>
# - test set prediction accuracy(+-10): 25.35 % <br>
# <br>
#
# ### <오차범위 20>
# - train set prediction accuracy(+-20): 68.68 % <br>
# - test set prediction accuracy(+-20): 56.34 % <br>
#
# ## 2. 임의+선별+PSQI
# ### <오차범위 3>
# - train set prediction accuracy(+-3): 20.28 % <br>
# - test set prediction accuracy(+-3): 11.27 % <br>
# <br>
#
# ### <오차범위 5>
# - train set prediction accuracy(+-5): 36.65 % <br>
# - test set prediction accuracy(+-5): 18.31 % <br>
# <br>
#
# ### <오차범위 10>
# - train set prediction accuracy(+-10): 63.35 % <br>
# - test set prediction accuracy(+-10): 28.17 % <br>
# <br>
#
# ### <오차범위 20>
# - train set prediction accuracy(+-20): 89.68 % <br>
# - test set prediction accuracy(+-20): 56.34 % <br>
#
#
# ## 3. PSQI+AGE+SEX+BMI+Fat+Fat_percentage+Waist
# ### <오차범위 3>
# - train set prediction accuracy(+-3): 26.69 % <br>
# - test set prediction accuracy(+-3): 9.86 % <br>
# <br>
#
# ### <오차범위 5>
# - train set prediction accuracy(+-5): 40.93 % <br>
# - test set prediction accuracy(+-5): 15.49 % <br>
# <br>
#
# ### <오차범위 10>
# - train set prediction accuracy(+-10): 67.26 % <br>
# - test set prediction accuracy(+-10): 35.21 % <br>
# <br>
#
# ### <오차범위 20>
# - train set prediction accuracy(+-20): 90.04 % <br>
# - test set prediction accuracy(+-20): 66.20 % <br>

# %% [markdown]
# # <Y=TG>
# ## 1. 임의+선별
# ### <오차범위 3>
# - train set prediction accuracy(+-3): 8.90 % <br>
# - test set prediction accuracy(+-3): 8.45 % <br>
# <br>
#
# ### <오차범위 5>
# - train set prediction accuracy(+-5): 14.23 % <br>
# - test set prediction accuracy(+-5): 14.08 % <br>
# <br>
#
# ### <오차범위 10>
# - train set prediction accuracy(+-10): 26.69 % <br>
# - test set prediction accuracy(+-10): 28.17 % <br>
# <br>
#
# ### <오차범위 20>
# - train set prediction accuracy(+-20): 49.82 % <br>
# - test set prediction accuracy(+-20): 53.52 % <br>
#
# ## 2. 임의+선별+PSQI
# ### <오차범위 3>
# - train set prediction accuracy(+-3): 12.46 % <br>
# - test set prediction accuracy(+-3): 7.04 % <br>
# <br>
#
# ### <오차범위 5>
# - train set prediction accuracy(+-5): 22.42 % <br>
# - test set prediction accuracy(+-5): 9.86 % <br>
# <br>
#
# ### <오차범위 10>
# - train set prediction accuracy(+-10): 38.08 % <br>
# - test set prediction accuracy(+-10): 21.13 % <br>
# <br>
#
# ### <오차범위 20>
# - train set prediction accuracy(+-20): 62.99 % <br>
# - test set prediction accuracy(+-20): 40.85 % <br>
#
#
# ## 3. PSQI+AGE+SEX+BMI+Fat+Fat_percentage+Waist
# ### <오차범위 3>
# - train set prediction accuracy(+-3): 7.83 % <br>
# - test set prediction accuracy(+-3): 2.82 % <br>
# <br>
#
# ### <오차범위 5>
# - train set prediction accuracy(+-5): 14.59 % <br>
# - test set prediction accuracy(+-5): 9.86 % <br>
# <br>
#
# ### <오차범위 10>
# - train set prediction accuracy(+-10): 36.30 % <br>
# - test set prediction accuracy(+-10): 19.72 % <br>
# <br>
#
# ### <오차범위 20>
# - train set prediction accuracy(+-20): 61.57 % <br>
# - test set prediction accuracy(+-20): 43.66 % <br>
